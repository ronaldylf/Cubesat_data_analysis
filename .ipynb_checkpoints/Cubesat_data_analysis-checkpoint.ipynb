# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("Setup complete")
# Out:
# Setup complete

# %%
# lendo os dados do arquivo bruto que virá do cartãoSD do satélite
data_path = './brute_data/telemetry.json'
telemetry_data = pd.read_json(data_path, convert_dates=True)

# %%
# mostrando os dados
telemetry_data
# Out:
#                           giroscopio          acelerometro  equipe   pressao  \
# 0                [-6.18, 1.27, 0.24]  [-0.03, -0.03, 0.92]      33  101087.3
# 1              [-4.68, -0.55, -1.56]  [-0.03, -0.03, 0.91]      33  101086.8
# 2                 [-6.3, 1.56, 0.27]  [-0.03, -0.03, 0.91]      33  101085.6
# 3                [-5.92, 2.91, 0.85]   [-0.04, -0.04, 0.9]      33  101081.7
# 4   [-6.42, 1.3599999999999999, 0.2]  [-0.03, -0.03, 0.91]      33  101079.3
# ..                               ...                   ...     ...       ...
# 92               [-5.45, 1.54, 0.34]  [-0.04, -0.02, 0.92]      33  101088.9
# 93               [-5.78, 1.44, 0.27]  [-0.04, -0.02, 0.92]      33  101084.0
# 94               [-5.55, 1.31, 0.38]  [-0.04, -0.03, 0.91]      33  101084.8
# 95               [-5.53, 1.49, 0.09]  [-0.04, -0.02, 0.91]      33  101084.8
# 96               [-5.57, 1.37, 0.24]  [-0.03, -0.03, 0.91]      33  101085.1
#
#                                               payload  bateria  temperatura
# 0   {'umidade': 35.76, 'ECO2': 405, 'TVOC': 26, 't...    49.43        26.31
# 1   {'umidade': 35.45, 'ECO2': 413, 'TVOC': 29, 't...    48.50        26.34
# 2   {'umidade': 35.22, 'ECO2': 400, 'TVOC': 23, 't...    48.74        26.36
# 3   {'umidade': 34.99, 'ECO2': 400, 'TVOC': 23, 't...    49.00        26.38
# 4   {'umidade': 34.9, 'ECO2': 430, 'TVOC': 37, 'ti...    49.03        26.47
# ..                                                ...      ...          ...
# 92  {'umidade': 30.51, 'ECO2': 538, 'TVOC': 93, 't...    48.98        29.71
# 93  {'umidade': 30.49, 'ECO2': 550, 'TVOC': 100, '...    48.71        29.74
# 94  {'umidade': 29.98, 'ECO2': 545, 'TVOC': 98, 't...    48.36        29.81
# 95  {'umidade': 29.75, 'ECO2': 529, 'TVOC': 88, 't...    48.74        29.83
# 96  {'umidade': 29.69, 'ECO2': 540, 'TVOC': 94, 't...    48.42        29.86
#
# [97 rows x 7 columns]

# %%
# calcula a média dos valores dos gases poluentes
sum_tvoc = 0
sum_eco2 = 0

for index, row in telemetry_data.iterrows():
    sum_tvoc += row['payload']['TVOC']
    sum_eco2 += row['payload']['ECO2']

num_rows = len(telemetry_data)
average_tvoc = round(sum_tvoc / num_rows, 2)
average_eco2 = round(sum_eco2 / num_rows, 2)

print(f"média TVOC: {average_tvoc}")
print(f"média ECO2: {average_eco2}")
# Out:
# média TVOC: 60.53
# média ECO2: 476.52

# %%
cor_esperado = 'blue'
cor_real = 'orange'

categorias = ( #categoria / valor esperado / valor real
    ["TVOC", 50, average_tvoc],
    ["ECO2", 800, average_eco2]
)

for item in categorias:
    # Cria um DataFrame com os dados
    average_data = pd.DataFrame({
        'Categoria': [item[0]],
        'Esperado': [item[1]],
        'Real': [item[2]]
    })
    
    # Seta a coluna 'Categoria' como index
    average_data.set_index('Categoria', inplace=True)
    
    # Plota o gráfico de barras
    ax = average_data.plot(kind='bar', color=[cor_esperado, cor_real], width=0.8, figsize=(10, 6))
    
    # Adiciona os labels e o título
    #plt.xlabel('Gases')
    plt.ylabel('Valores (ppb)')
    plt.title(f'Ideal x Dados reais ({item[0]})')
    # Adicionando a legenda
    ax.legend(['Ideal', 'Real'])
    
    # Mostra o gráfico
    plt.show()

# %%
data = {
    'Valor': [],
    'Tempo': []
}

for item in telemetry_data['payload']:
    data['Valor'].append(item['TVOC'])
    data['Tempo'].append(pd.to_datetime(item['time'], unit='s'))

df_payload = pd.DataFrame(data)
print(df_payload)

# Plotting
plt.figure(figsize=(10, 6))
#plt.plot(df_payload['Tempo'], df_payload['Valor'], marker='o', linestyle='-') # com ponto
plt.plot(df_payload['Tempo'], df_payload['Valor'], linestyle='-')

# Adding labels and title
plt.xlabel('Tempo')
plt.ylabel('TVOC')
plt.title('Gráfico TVOCs x Tempo')

# Display the plot
plt.show()
# Out:
#     Valor               Tempo
# 0      26 1993-08-01 18:23:29
# 1      29 1993-08-01 18:23:37
# 2      23 1993-08-01 18:23:44
# 3      23 1993-08-01 18:23:51
# 4      37 1993-08-01 18:23:57
# ..    ...                 ...
# 92     93 1993-08-01 18:37:37
# 93    100 1993-08-01 18:37:45
# 94     98 1993-08-01 18:38:05
# 95     88 1993-08-01 18:38:12
# 96     94 1993-08-01 18:38:18
#
# [97 rows x 2 columns]

# %%
data = {
    'Valor': [],
    'Tempo': []
}

for item in telemetry_data['payload']:
    data['Valor'].append(item['ECO2'])
    data['Tempo'].append(pd.to_datetime(item['time'], unit='s'))

df_payload = pd.DataFrame(data)
print(df_payload)

# Plotting
plt.figure(figsize=(10, 6))
#plt.plot(df_payload['Tempo'], df_payload['Valor'], marker='o', linestyle='-') # com ponto
plt.plot(df_payload['Tempo'], df_payload['Valor'], linestyle='-')

# Adding labels and title
plt.xlabel('Tempo')
plt.ylabel('ECO2')
plt.title('Gráfico eCO2 x Tempo')

# Display the plot
plt.show()
df_payload
# Out:
#     Valor               Tempo
# 0     405 1993-08-01 18:23:29
# 1     413 1993-08-01 18:23:37
# 2     400 1993-08-01 18:23:44
# 3     400 1993-08-01 18:23:51
# 4     430 1993-08-01 18:23:57
# ..    ...                 ...
# 92    538 1993-08-01 18:37:37
# 93    550 1993-08-01 18:37:45
# 94    545 1993-08-01 18:38:05
# 95    529 1993-08-01 18:38:12
# 96    540 1993-08-01 18:38:18
#
# [97 rows x 2 columns]
#     Valor               Tempo
# 0     405 1993-08-01 18:23:29
# 1     413 1993-08-01 18:23:37
# 2     400 1993-08-01 18:23:44
# 3     400 1993-08-01 18:23:51
# 4     430 1993-08-01 18:23:57
# ..    ...                 ...
# 92    538 1993-08-01 18:37:37
# 93    550 1993-08-01 18:37:45
# 94    545 1993-08-01 18:38:05
# 95    529 1993-08-01 18:38:12
# 96    540 1993-08-01 18:38:18
#
# [97 rows x 2 columns]

# %%
items = [
    {'title': "Gráfico Temperatura x Tempo", 'key': "temperatura", 'ylabel': "Temperatura(°C)"},
    {'title': "Gráfico Umidade x Tempo", 'key': "umidade", 'ylabel': "Umidade(%)"},
    {'title': "Gráfico Bateria x Tempo", 'key': "bateria", 'ylabel': "Bateria(%)"},
    {'title': "Gráfico Pressão x Tempo", 'key': "pressao", 'ylabel': "Pressão(Pa)"},
]

for item in items:
    data = {
        'Valor': [],
        'Tempo': []
    }

    for index, row in telemetry_data.iterrows():
        try:
            data['Valor'].append(row[item['key']])
        except KeyError:
            data['Valor'].append(row['payload'][item['key']])
        data['Tempo'].append(pd.to_datetime(row['payload']['time'], unit='s'))
    
    df_payload = pd.DataFrame(data)
    print(df_payload)
    
    # Plotting
    plt.figure(figsize=(10, 6))
    #plt.plot(df_payload['Tempo'], df_payload['Valor'], marker='o', linestyle='-') # com ponto
    plt.plot(df_payload['Tempo'], df_payload['Valor'], linestyle='-')
    
    # Adding labels and title
    plt.xlabel('Tempo')
    plt.ylabel(item['ylabel'])
    plt.title(item['title'])
    
    # Display the plot
    plt.show()
# Out:
#     Valor               Tempo
# 0   26.31 1993-08-01 18:23:29
# 1   26.34 1993-08-01 18:23:37
# 2   26.36 1993-08-01 18:23:44
# 3   26.38 1993-08-01 18:23:51
# 4   26.47 1993-08-01 18:23:57
# ..    ...                 ...
# 92  29.71 1993-08-01 18:37:37
# 93  29.74 1993-08-01 18:37:45
# 94  29.81 1993-08-01 18:38:05
# 95  29.83 1993-08-01 18:38:12
# 96  29.86 1993-08-01 18:38:18
#
# [97 rows x 2 columns]
#     Valor               Tempo
# 0   35.76 1993-08-01 18:23:29
# 1   35.45 1993-08-01 18:23:37
# 2   35.22 1993-08-01 18:23:44
# 3   34.99 1993-08-01 18:23:51
# 4   34.90 1993-08-01 18:23:57
# ..    ...                 ...
# 92  30.51 1993-08-01 18:37:37
# 93  30.49 1993-08-01 18:37:45
# 94  29.98 1993-08-01 18:38:05
# 95  29.75 1993-08-01 18:38:12
# 96  29.69 1993-08-01 18:38:18
#
# [97 rows x 2 columns]
#     Valor               Tempo
# 0   49.43 1993-08-01 18:23:29
# 1   48.50 1993-08-01 18:23:37
# 2   48.74 1993-08-01 18:23:44
# 3   49.00 1993-08-01 18:23:51
# 4   49.03 1993-08-01 18:23:57
# ..    ...                 ...
# 92  48.98 1993-08-01 18:37:37
# 93  48.71 1993-08-01 18:37:45
# 94  48.36 1993-08-01 18:38:05
# 95  48.74 1993-08-01 18:38:12
# 96  48.42 1993-08-01 18:38:18
#
# [97 rows x 2 columns]
#        Valor               Tempo
# 0   101087.3 1993-08-01 18:23:29
# 1   101086.8 1993-08-01 18:23:37
# 2   101085.6 1993-08-01 18:23:44
# 3   101081.7 1993-08-01 18:23:51
# 4   101079.3 1993-08-01 18:23:57
# ..       ...                 ...
# 92  101088.9 1993-08-01 18:37:37
# 93  101084.0 1993-08-01 18:37:45
# 94  101084.8 1993-08-01 18:38:05
# 95  101084.8 1993-08-01 18:38:12
# 96  101085.1 1993-08-01 18:38:18
#
# [97 rows x 2 columns]
